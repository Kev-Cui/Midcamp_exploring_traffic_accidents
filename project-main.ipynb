# %%
import pymysql
from sqlalchemy import create_engine
from getpass import getpass
import pandas as pd
import numpy as np
password=getpass()
connection_string = 'mysql+pymysql://root:'+password+'@localhost/uk_traffic_flow_and_accidents'
engine = create_engine(connection_string)
# Out:
# ········

# %%
df = pd.read_sql_table('accidents', engine)

# %%
df_num = df.select_dtypes('number')
df_cat = df.select_dtypes(exclude='number')

# %%
#Plot categorical values and visually inspect:
import seaborn as sns
import matplotlib.pyplot as plt

# %%
for column in df_cat.drop(['lsoa_of_accident_location', 'local_authority_(highway)', 'time', 'date'],axis=1).columns:
    display(df_cat[column].value_counts())
# Out:
# road_type
# Single carriageway    1100508
# Dual carriageway       216861
# Roundabout              98508
# One way street          30329
# Slip road               15357
# Unknown                  8214
# Name: count, dtype: int64
# junction_control
# Giveway or uncontrolled     715660
# Not junction                591698
# Automatic traffic signal    150984
# Stop Sign                     9013
# Authorised person             2422
# Name: count, dtype: int64
# pedestrian_crossing-human_control
# None within 50 metres                 1461117
# Control by other authorised person       5094
# Control by school crossing patrol        3550
# Name: count, dtype: int64
# pedestrian_crossing-physical_facilities
# No physical crossing within 50 meters          1225316
# Pedestrian phase at traffic signal junction      97160
# non-junction pedestrian crossing                 77292
# Zebra crossing                                   38940
# Central refuge                                   26845
# ...

# %%
# don't run this, I just saved the output becacuse this took me 1 hour to run

# for column in df_cat.drop(['lsoa_of_accident_location', 'local_authority_(highway)', 'time', 'date'],axis=1).columns:
#     sns.catplot(data=df, kind="bar", col=column, col_wrap=4)

# %%
for column in df_cat.drop(['lsoa_of_accident_location', 'local_authority_(highway)', 'time', 'date'],axis=1).columns:
    sns.displot(data=df,x=column)
    plt.gca().set_xticklabels(plt.gca().get_xticklabels(), rotation=45, horizontalalignment='right')
    plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_10112\2767924681.py:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_xticklabels(plt.gca().get_xticklabels(), rotation=45, horizontalalignment='right')
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_10112\2767924681.py:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_xticklabels(plt.gca().get_xticklabels(), rotation=45, horizontalalignment='right')
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# ...

# %%
for column in df_num.columns:
    sns.boxplot(data=df,x=column)
    plt.show()

# %%
df_num
# Out:
#          location_easting_osgr  location_northing_osgr  longitude   latitude  \
# 0                       525680                  178240  -0.191170  51.489096
# 1                       524170                  181650  -0.211708  51.520075
# 2                       524520                  182240  -0.206458  51.525301
# 3                       526900                  177530  -0.173862  51.482442
# 4                       528060                  179040  -0.156618  51.495752
# ...                        ...                     ...        ...        ...
# 1469772                 310037                  597647  -3.417278  55.264773
# 1469773                 321509                  574063  -3.230255  55.054855
# 1469774                 321337                  566365  -3.230826  54.985668
# 1469775                 323869                  566853  -3.191397  54.990446
# 1469776                 314072                  579971  -3.348426  55.106700
#
# ...

# %%
df_num['number_of_casualties'].min()
# Out:
# 1
